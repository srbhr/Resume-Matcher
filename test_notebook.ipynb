# %%
# Out:
# {'unique_id': '2485ba46-bacc-420d-a660-0d97e15cf422', 'resume_data': 'Saurabh Rai\nSoftware Developer\nbit.ly/srbhr\n srbhr\n Saurabh Rai\n srbh077@gmail.com\n +91 7011378601\nEXPERIENCE\nTATACONSULTANCYSERVICES(AON) | SOFTWARE DEVELOPER (FULL‑STACK)\nOctober2021–Current|NewDelhi,India\nÔ Developed the UI component for an internal application using Angular , T ypescript,\nHTML5, CSS3, PrimeNG and Bootstrap.\nÔ Worked on back-end web development and design using Java, Groovy, REST API,\nSpring Boot and Gradle.\nÔ Used asynchronous calls to consume RESTful web services to fetch data from\nserver side and then render .\nINVIDEDEVELOPERCOMMUNITY | DEVELOPER RELATIONS\nSeptember2021–Current|Remote,India\nÔ Managed & hosted Git Commit Show , an online remote conference for software\ndevelopers.\nÔ Initiated aseries of marketing campaigns including blog posts, reaching to\ndeveloper communities to ensure steady participation and enthusiasm of people\nduring the live show .\nÔ Identify, crea
# ...
